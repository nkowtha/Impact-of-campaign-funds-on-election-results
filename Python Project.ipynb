# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import os
os.getcwd()
# Out:
# '/Users/rajib/Documents/Python'

# %%
path=input("Input the directory of the file:\t")
# Out:
# Input the directory of the file:	/Users/rajib/Documents/Python

# %%
os.listdir(path)
# Out:
# ['df2016Q1.csv',
#  'CandidateSummaryAction1.csv',
#  '.DS_Store',
#  'Python Assignment 3.ipynb',
#  'Untitled.ipynb',
#  'Python Assignment 4.ipynb',
#  'Fall2021_Assignement3.docx',
#  'Python Mock.ipynb',
#  'Python Assignment 2.ipynb',
#  'Python Group.ipynb',
#  'Fall2021_Assignement2.docx',
#  'Fall2021_Assignement1.docx',
#  'Practice.ipynb',
#  'Lab 5 Solutions.ipynb',
#  'Python Assignment-1.ipynb',
#  '.ipynb_checkpoints',
#  'Lab 3 Solutions.ipynb',
#  'CandidateSummaryAction1 2.csv',
#  'Lab 4 Solutions.ipynb',
#  'Python Project.ipynb']

# %%
os.chdir(path)
data=pd.read_csv('CandidateSummaryAction1.csv')
data.head()
# Out:
#       can_id           can_nam can_off can_off_sta  can_off_dis can_par_aff  \
# 0  H2GA12121  ALLEN, RICHARD W       H          GA         12.0         REP
# 1  H6PA02171     EVANS, DWIGHT       H          PA          2.0         DEM
# 2  H6FL04105  RUTHERFORD, JOHN       H          FL          4.0         REP
# 3  H4MT01041     ZINKE, RYAN K       H          MT          0.0         REP
# 4  H8CA09060      LEE, BARBARA       H          CA         13.0         DEM
#
#   can_inc_cha_ope_sea                 can_str1 can_str2       can_cit  ...  \
# 0           INCUMBENT          2237 PICKENS RD      NaN       AUGUSTA  ...
# 1          CHALLENGER              PO BOX 6578      NaN  PHILADELPHIA  ...
# 2                OPEN  3817 VICKERS LAKE DRIVE      NaN  JACKSONVILLE  ...
# 3           INCUMBENT             409 2ND ST W      NaN     WHITEFISH  ...
# 4           INCUMBENT     409 13TH ST, 17TH FL      NaN       OAKLAND  ...
#
# ...

# %%
df=pd.DataFrame(data)
df.head()
# Out:
#       can_id           can_nam can_off can_off_sta  can_off_dis can_par_aff  \
# 0  H2GA12121  ALLEN, RICHARD W       H          GA         12.0         REP
# 1  H6PA02171     EVANS, DWIGHT       H          PA          2.0         DEM
# 2  H6FL04105  RUTHERFORD, JOHN       H          FL          4.0         REP
# 3  H4MT01041     ZINKE, RYAN K       H          MT          0.0         REP
# 4  H8CA09060      LEE, BARBARA       H          CA         13.0         DEM
#
#   can_inc_cha_ope_sea                 can_str1 can_str2       can_cit  ...  \
# 0           INCUMBENT          2237 PICKENS RD      NaN       AUGUSTA  ...
# 1          CHALLENGER              PO BOX 6578      NaN  PHILADELPHIA  ...
# 2                OPEN  3817 VICKERS LAKE DRIVE      NaN  JACKSONVILLE  ...
# 3           INCUMBENT             409 2ND ST W      NaN     WHITEFISH  ...
# 4           INCUMBENT     409 13TH ST, 17TH FL      NaN       OAKLAND  ...
#
# ...

# %%
df.isna()
# Out:
#       can_id  can_nam  can_off  can_off_sta  can_off_dis  can_par_aff  \
# 0      False    False    False        False        False        False
# 1      False    False    False        False        False        False
# 2      False    False    False        False        False        False
# 3      False    False    False        False        False        False
# 4      False    False    False        False        False        False
# ...      ...      ...      ...          ...          ...          ...
# 1809   False    False    False        False        False        False
# 1810   False    False    False        False        False        False
# 1811   False    False    False        False        False        False
# 1812   False    False    False        False         True        False
# 1813   False    False    False        False         True        False
#
#       can_inc_cha_ope_sea  can_str1  can_str2  can_cit  ...  \
# 0                   False     False      True    False  ...
# ...

# %%
df.dropna(how='all', inplace=True)
df.shape
# Out:
# (1814, 51)

# %%
df.fillna(0)
# Out:
#          can_id                       can_nam can_off can_off_sta  \
# 0     H2GA12121              ALLEN, RICHARD W       H          GA
# 1     H6PA02171                 EVANS, DWIGHT       H          PA
# 2     H6FL04105              RUTHERFORD, JOHN       H          FL
# 3     H4MT01041                 ZINKE, RYAN K       H          MT
# 4     H8CA09060                  LEE, BARBARA       H          CA
# ...         ...                           ...     ...         ...
# 1809  P60005931   BUTTOCKS, SYDNEYS VOLUPTOUS       P          US
# 1810  S6CA00568                MOLNAR, ROBERT       S          CA
# 1811  S6MD03524               HOLMES, GREGORY       S          MD
# 1812  H6AS00031  HUNKIN-FINAU, VAITINASA SALU       H          AS
# 1813  H6AK00235               LINDBECK, STEVE       H          AK
#
#       can_off_dis can_par_aff can_inc_cha_ope_sea                 can_str1  \
# 0            12.0         REP           INCUMBENT          2237 PICKENS RD
# ...

# %%
df['cov_sta_dat'] = pd.to_datetime(df['cov_sta_dat'])
df['cov_end_dat'] = pd.to_datetime(df['cov_end_dat'])

df['campaign_duration'] = (df['cov_end_dat'] - df['cov_sta_dat']).dt.days

# %%
df.head()
# Out:
#       can_id           can_nam can_off can_off_sta  can_off_dis can_par_aff  \
# 0  H2GA12121  ALLEN, RICHARD W       H          GA         12.0         REP
# 1  H6PA02171     EVANS, DWIGHT       H          PA          2.0         DEM
# 2  H6FL04105  RUTHERFORD, JOHN       H          FL          4.0         REP
# 3  H4MT01041     ZINKE, RYAN K       H          MT          0.0         REP
# 4  H8CA09060      LEE, BARBARA       H          CA         13.0         DEM
#
#   can_inc_cha_ope_sea                 can_str1 can_str2       can_cit  ...  \
# 0           INCUMBENT          2237 PICKENS RD      NaN       AUGUSTA  ...
# 1          CHALLENGER              PO BOX 6578      NaN  PHILADELPHIA  ...
# 2                OPEN  3817 VICKERS LAKE DRIVE      NaN  JACKSONVILLE  ...
# 3           INCUMBENT             409 2ND ST W      NaN     WHITEFISH  ...
# 4           INCUMBENT     409 13TH ST, 17TH FL      NaN       OAKLAND  ...
#
# ...

# %%
def process_missing_data(data, threshold):
    #calculate all columns with missing values percentage greater than the threshold
    missing_percentage = (df.isna().sum()/len(df))*100
    
    #check for threshold condition
    missing_filtered = missing_percentage[missing_percentage >= threshold] 
    
    #select the candidate columns to a list
    drop_cols = missing_filtered.index.tolist()
    
    # drop the columns in the data
    df.drop(columns=drop_cols, inplace=True)
    
    return df.shape
process_missing_data(df,90)
# Out:
# (1814, 42)

# %%
df['can_off'].value_counts(normalize=True, sort=True) * 100
# Out:
# H    78.776185
# S    12.513782
# P     8.710033
# Name: can_off, dtype: float64

# %%
if df['can_par_off']='REP':
